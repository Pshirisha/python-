# %% [markdown]
# # python
# ## python
# ### python
# #### python
# ##### python
# ###### python
# 1. python
#      1. inventor
#      2. year
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 1. Keywords:
#       1. keywords are the pre defined words. we cant change the meaning of the keyword.
#       2. the main use of keyword is,if we use the keyword the interpreter can understand the user for the furter operations.
#       3. keywords are represented in lowercase.
#       4. except false,true and none all are in lowercase only.
#       5. we have 33 keywords in python.

# %%
help("keywords")
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not

# %% [markdown]
# ## 2. variables:

# %%
x = 10
y = 34.5
z = "a"
type(x)
# Out:
# int

# %%
type(y)
# Out:
# float

# %%
type(z)
# Out:
# str

# %% [markdown]
# ## 3. input() and print() functions:

# %%
print("hello world")   #if we want any matter to print use collan
print(x)
print("x")
print("the value of x is",x)
# Out:
# hello world
# 10
# x
# the value of x is 10

# %%
y=int(input("enter y values"))
print(type(y))
# Out:
# enter y values2
# <class 'int'>

# %% [markdown]
# --> create two variables with the names age and name of the candidate. you need to accept values from the user and display the values as follows
#   my name is ----- and my age is ----

# %%
name=input("enter your name")
age=int(input("enter your age"))
print("my name is ",name,"and my age is ",age)
# Out:
# enter your nameghaskxm
# enter your age21
# my name is  ghaskxm  and my age is  21

# %%
print("my name is",name, end="")  # using two print functions but to get output in one line
print("my age is ",age)
# Out:
# my name is ghaskxm my age is  21

# %%
print("my name is",name,"\n" "myage is",age) # using a single print function but getting two outputs
# Out:
# my name is ghaskxm
# myage is 21

# %% [markdown]
# ## 4. indentations:

# %% [markdown]
# 1.we use indentation in the looping statements.
# 2.if we are using loop then in other programming language we use flower braces,in python we use a tab space.
# 3.if we use a loop the colon in the last is mandatory.if we dnt give the colon symbol then it wont take any tab spaces.

# %%
if age>18:
    print("eligible")
    print("the age is above 18")
    if age<5:
        print("the age is below 5")
print("bye")
# Out:
# eligible
# the age is above 18
# bye

# %% [markdown]
# ## 5. data types:
#
#    it will give the type of the data.
#
# 1.static datatype:
#          the memory allocation is done at the assingnment time only.
# 2,dynamic datatype:
#          the memory allocation is done at the run time.
#          python supports dynamic type.
#
# ## python data type:
#  1. fundamental
#        1. int      #number without decimal is int
#        2. float    #number with decimal is float
#        3. complex  #number with imaginary part is complex
#        4. boolean  #will return true or false
#        5. strings
#  2. collection
#        1.  list
#        2. tuple
#        3. set
#        4. dictionary

# %%
x = 12
y = 3.56
z = 6+5j

# %%
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %%
c= complex(5,6)
print(c)
# Out:
# (5+6j)

# %%
print("real part is",c.real)           #or use c.real  
print("imaginary part is",c.imag)      # use c.imag
# Out:
# real part is 5.0
# imaginary part is 6.0

# %%
12<34
# Out:
# True

# %%
43<1
# Out:
# False

# %%
help(str)
# Out:
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to sys.getdefaultencoding().
#  |  errors defaults to 'strict'.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Return a formatted version of the string as described by format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
# ...

# %%
name ="shirisha"
len(name)
# Out:
# 8

# %% [markdown]
# ## build in functions in string:

# %%
name.capitalize()   # to print starting letter capital(capitalize)
# Out:
# 'Shirisha'

# %%
name.center(80)    #to print in the center(center)
# Out:
# '                                    shirisha                                    '

# %%
name.center(12,'*')  #after filling the remaining space will fill with the given symbol(fillchar)
# Out:
# '**shirisha**'

# %%
name='Shirisha'

# %%
name.casefold()     #convert uppercase into lowercase(casefold)
# Out:
# 'shirisha'

# %%
name.count("i")    #gives the number of times repeated in the given string "shirisha"(count)
# Out:
# 2

# %%
name.endswith("i")# gives true if the given string is ends with the given tupple(endswith) as i is not the end letter it gave false
# Out:
# False

# %%
name.endswith("a")  #as the last letter is a it gave true for the given result
# Out:
# True

# %%
name.startswith("a") # opp to the endswith(startwith)
# Out:
# False

# %%
name.startswith("S")
# Out:
# True

# %%
name.expandtabs(  )  #gives tab space btwn the strings  (expandtabs)
# Out:
# 'Shirisha'

# %%
name.encode()  #print from bluff type of code in place of (encode)
# Out:
# b'Shirisha'

# %%
name.find("i")  # (find)
# Out:
# -1

# %%
print("hello {0} your age is{1}".format("shirisha",12))#we will give the parameters and replace it (format)
# Out:
# hello shirisha your age is12

# %%
name="python is a easy language"#we can know the index number of the given substring(index)
name.index("easy")
# Out:
# 12

# %%
name.isalnum() #gives true if the string is alphanumeric,it contains spaces so it is false(isalnum)
# Out:
# False

# %%
name="shirisha" #it contains only alphanumeric(isalnum)
name.isalnum()
# Out:
# True

# %%
name.isalpha()#it should contain only alphabets(isalpha)
# Out:
# True

# %%
name="123 sgujrkjgejsd" # ex of is (isalpha)
name.isalpha()
# Out:
# False

# %%
name.isdecimal()#it should contain only decimals(isdecimal)
# Out:
# False

# %%
name="1234567" #it contain only decimals so true(isdecimal)
name.isdecimal()
# Out:
# True

# %%
name.isdigit()#it should contain only decimals(isdigit)will support /u
# Out:
# True

# %%
name.isidentifier()#(is.identifier) starting shuld be alpha
# Out:
# False

# %%
name="siri123"     #(is.identifier) starting is alpha
name.isidentifier()
# Out:
# True

# %%
name.islower()#given string is in lower case returns true(is.lower)
# Out:
# True

# %%
name='Shirisha'#(is.lower)string has uppercase so false
name.islower()
# Out:
# False

# %%
name.isnumeric()#given string has alphabets(is.numeric)
# Out:
# False

# %%
name="123456" #same like is.digit
name.isnumeric()
# Out:
# True

# %%
name.isprintable()#gives true when the string is printable or which appear in the screen
# Out:
# True

# %%
name="\n"   #\n is not a printable function
name.isprintable()
# Out:
# False
